# %% [markdown]
# <a href="https://colab.research.google.com/github/Aragnzlz/ARTICULO-ESTIMACION-AFLUENCIA-METROBUS/blob/main/ARTICULO_VF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar datos desde un archivo Excel
data = pd.read_excel('AFLUENCIA_TOTAL.xlsx')
data #Imprimir datos
# Out:
#           FECHA  AFLUENCIA
# 0    2011-02-09      94471
# 1    2011-02-10      95296
# 2    2011-02-11      98210
# 3    2011-02-12      73530
# 4    2011-02-13      51138
# ...         ...        ...
# 5009 2024-10-27      93165
# 5010 2024-10-28     185470
# 5011 2024-10-29     203048
# 5012 2024-10-30     203777
# 5013 2024-10-31     205492
#
# [5014 rows x 2 columns]

# %%
# Gráfico de la serie temporal
plt.figure(figsize=(8, 4))  # Ajustar tamaño del gráfico

plt.plot(data['FECHA'], data['AFLUENCIA'], color='#8B0000', linewidth=0.5, label='Afluencia')

# Formato de los ejes
plt.title('Demanda diaria de la Línea 1 del Metrobús (2012 - 2024)', fontsize=12,  color = "gray") # Ajustar tamaño del título
plt.xlabel('Año', fontsize=12,  color = "gray")  # Ajustar tamaño de etiquetas
plt.ylabel('Afluencia', fontsize=12, color = "gray")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(fontsize=8) # Ajustar tamaño de la leyenda
plt.tight_layout()  # Ajustar diseño para evitar superposición
# Mostrar el gráfico
plt.show()

# %%
# Convertir la columna 'FECHA' a datetime si no lo está ya
data['FECHA'] = pd.to_datetime(data['FECHA'])
#ESTABLECER LA FECHA COMO INDICE
data.set_index('FECHA', inplace=True)

# %%
# Gráfico serie temporal con zoom
# ==============================================================================
zoom = ('2020-01-01','2021-12-31')
fig = plt.figure(figsize=(10, 4))
grid = plt.GridSpec(nrows=10, ncols=1, hspace=0.6, wspace=0)
main_ax = fig.add_subplot(grid[1:3, :])
zoom_ax = fig.add_subplot(grid[5:, :])
data.AFLUENCIA.plot(ax=main_ax, c='black', alpha=0.5, linewidth=0.5)
min_y = min(data.AFLUENCIA)
max_y = max(data.AFLUENCIA)
main_ax.fill_between(zoom, min_y, max_y, facecolor='#8B0000', alpha=0.5, zorder=0)
main_ax.set_xlabel('')
data.loc[zoom[0]: zoom[1]].AFLUENCIA.plot(ax=zoom_ax, color='#8B0000', linewidth=1)
main_ax.set_title(f'Demanda diaria de la Línea 1 del Metrobús (2020 - 2022)', fontsize=12, color = "gray")
zoom_ax.set_xlabel(f'Mes', fontsize=10, color = "gray")
plt.subplots_adjust(hspace=1)

# %%
# Gráfico serie temporal con zoom
# ==============================================================================
zoom = ('2023-01-01','2023-12-31')
fig = plt.figure(figsize=(10, 4))
grid = plt.GridSpec(nrows=10, ncols=1, hspace=0.6, wspace=0)
main_ax = fig.add_subplot(grid[1:3, :])
zoom_ax = fig.add_subplot(grid[5:, :])
data.AFLUENCIA.plot(ax=main_ax, c='black', alpha=0.5, linewidth=0.5)
min_y = min(data.AFLUENCIA)
max_y = max(data.AFLUENCIA)
main_ax.fill_between(zoom, min_y, max_y, facecolor='#8B0000', alpha=0.5, zorder=0)
main_ax.set_xlabel('')
data.loc[zoom[0]: zoom[1]].AFLUENCIA.plot(ax=zoom_ax, color='#8B0000', linewidth=1)
main_ax.set_title(f'Demanda diaria de la Línea 1 del Metrobús (2012 - 2024)', fontsize=12, color = "gray")
zoom_ax.set_title(f'Demanda diaria de la Línea 1 del Metrobús (2023)', fontsize=12, color = "gray")
zoom_ax.set_xlabel('Mes',fontsize=10, color = "gray")
plt.subplots_adjust(hspace=1)

# %%
# Cargar datos desde un archivo Excel
datos = pd.read_excel('AFLUENCIA_2023.xlsx')
datos #Imprimir datos
# Out:
#          FECHA  AFLUENCIA
# 0   2023-01-01      45541
# 1   2023-01-02     128298
# 2   2023-01-03     147638
# 3   2023-01-04     154646
# 4   2023-01-05     166177
# ..         ...        ...
# 658 2024-10-20     106959
# 659 2024-10-21     184116
# 660 2024-10-22     207815
# 661 2024-10-23     197911
# 662 2024-10-24     208828
#
# [663 rows x 2 columns]

# %%
datos['FECHA'] = pd.to_datetime(datos['FECHA'], format='%d/%m/%Y')
datos = datos.set_index('FECHA')
datos.head(2)
# Out:
#             AFLUENCIA
# FECHA
# 2023-01-01      45541
# 2023-01-02     128298

# %%
plt.figure(figsize=(8, 4))
sns.histplot(data['AFLUENCIA'], kde=True, color='#8B0000', bins=30)  # Ajusta el número de bins según tus datos
plt.title('Histograma y curva de densidad de la afluencia diaria de la línea 1 del Metrobús', fontsize=12, color="gray")
plt.xlabel('Afluencia', fontsize=12, color="gray")
plt.ylabel('Frecuencia', fontsize=12, color="gray")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
pip install fitter
# Out:
# Requirement already satisfied: fitter in /usr/local/lib/python3.10/dist-packages (1.7.1)
# Requirement already satisfied: click<9.0.0,>=8.1.6 in /usr/local/lib/python3.10/dist-packages (from fitter) (8.1.8)
# Requirement already satisfied: joblib<2.0.0,>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.4.2)
# Requirement already satisfied: loguru<0.8.0,>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (0.7.3)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (3.10.0)
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=0.23.4 in /usr/local/lib/python3.10/dist-packages (from fitter) (2.2.2)
# Requirement already satisfied: rich-click<2.0.0,>=1.7.2 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.8.5)
# Requirement already satisfied: scipy<2.0.0,>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from fitter) (1.13.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.65.1 in /usr/local/lib/python3.10/dist-packages (from fitter) (4.67.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.2->fitter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.23.4->fitter) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=0.23.4->fitter) (2024.2)
# Requirement already satisfied: rich>=10.7 in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (13.9.4)
# Requirement already satisfied: typing_extensions>=4 in /usr/local/lib/python3.10/dist-packages (from rich-click<2.0.0,>=1.7.2->fitter) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.2->fitter) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7->rich-click<2.0.0,>=1.7.2->fitter) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.7->rich-click<2.0.0,>=1.7.2->fitter) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click<2.0.0,>=1.7.2->fitter) (0.1.2)

# %%
from fitter import Fitter

# %%
import numpy as np
import pandas as pd

# %%
# Cargar datos desde un archivo Excel
datos = pd.read_excel('AFLUENCIA_2023.xlsx')
datos #Imprimir datos
# Out:
#          FECHA  AFLUENCIA
# 0   2023-01-01      45541
# 1   2023-01-02     128298
# 2   2023-01-03     147638
# 3   2023-01-04     154646
# 4   2023-01-05     166177
# ..         ...        ...
# 658 2024-10-20     106959
# 659 2024-10-21     184116
# 660 2024-10-22     207815
# 661 2024-10-23     197911
# 662 2024-10-24     208828
#
# [663 rows x 2 columns]

# %%
data = datos['AFLUENCIA'].values
f = Fitter(data, distributions=None)
f.fit()
print(f.summary())
# Out:
#                     sumsquare_error          aic          bic  kl_div  \
# skewcauchy             7.358484e-10  2559.629941  2573.120266     inf
# genlogistic            7.799817e-10  2524.905140  2538.395465     inf
# genhyperbolic          7.835709e-10  2529.189374  2551.673249     inf
# laplace_asymmetric     7.850805e-10  2525.435307  2538.925632     inf
# loggamma               8.613847e-10  2523.179460  2536.669785     inf
#
#                     ks_statistic     ks_pvalue
# skewcauchy              0.108442  3.033589e-07
# genlogistic             0.068706  3.636749e-03
# genhyperbolic           0.068518  3.764012e-03
# laplace_asymmetric      0.066786  5.144388e-03
# loggamma                0.068709  3.635006e-03

# %% [markdown]
# DIAGRAMA DE CAJAS

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import plotly.graph_objects as go
import plotly.io as pio
import plotly.offline as poff
pio.templates.default = "seaborn"
poff.init_notebook_mode(connected=True)
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams.update({'font.size':8})
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Cargar datos desde un archivo Excel
datos = pd.read_excel('AFLUENCIA_2023.xlsx')
datos #Imprimir datos
# Out:
#          FECHA  AFLUENCIA
# 0   2023-01-01      45541
# 1   2023-01-02     128298
# 2   2023-01-03     147638
# 3   2023-01-04     154646
# 4   2023-01-05     166177
# ..         ...        ...
# 658 2024-10-20     106959
# 659 2024-10-21     184116
# 660 2024-10-22     207815
# 661 2024-10-23     197911
# 662 2024-10-24     208828
#
# [663 rows x 2 columns]

# %%
# Conversión del formato fecha
# ==============================================================================
datos['FECHA'] = pd.to_datetime(datos['FECHA'], format='%d/%m/%Y')
datos = datos.set_index('FECHA')
datos.head(2)
# Out:
#             AFLUENCIA
# FECHA
# 2023-01-01      45541
# 2023-01-02     128298

# %%
# Distribución de la demanda por mes
# ==============================================================================
fig, ax = plt.subplots(figsize=(5.5, 2.5))
datos['MES'] = datos.index.month
datos.boxplot(column='AFLUENCIA', by='MES', ax=ax,)
datos.groupby('MES')['AFLUENCIA'].median().plot(style='o-', linewidth=0.8, ax=ax)
ax.set_ylabel('Afluencia', fontsize=12, color="gray")
ax.set_title('Distribución de la alfuencia diaria de la línea 1 del Metrobús por mes',fontsize=12, color="gray")
fig.suptitle('');

# %%
# Distribución de la demanda por día de la semana
# ==============================================================================
fig, ax = plt.subplots(figsize=(5.5, 2.5))
# Create a temporary column for the day of the week to avoid ambiguity.
datos['DIA_DE_LA_SEMANA'] = datos.index.day_of_week + 1
datos.boxplot(column='AFLUENCIA', by='DIA_DE_LA_SEMANA', ax=ax) # Use the temporary column for grouping.
datos.groupby('DIA_DE_LA_SEMANA')['AFLUENCIA'].median().plot(style='o-', linewidth=0.8, ax=ax) # Use the temporary column here too.
ax.set_ylabel('Afluencia',fontsize=12, color="gray")
ax.set_title('Distribución de la alfuencia diaria de la línea 1 del Metrobús por semana',fontsize=12, color="gray")
fig.suptitle('');

# %% [markdown]
# IMPLEMENTACIÓN DEL CODIGO

# %%
df = pd.read_excel('DATOS_AFLUENCIA_1.xlsx', parse_dates=['FECHA'], index_col='FECHA')

# Ver las primeras filas de los datos
print(df.head())

# Paso 1: Normalización de los datos
scaler = StandardScaler()
# Out:
#             AFLUENCIA
# FECHA
# 2017-01-01      48843
# 2017-01-02     136902
# 2017-01-03     148569
# 2017-01-04     139660
# 2017-01-05     146103

# %%
#Normalizamos solo la columna de la afluencia diaria
df['AFLUENCIA NORMALIZADA'] = scaler.fit_transform(df[['AFLUENCIA']])

# %%
df
# Out:
#             AFLUENCIA  AFLUENCIA NORMALIZADA
# FECHA
# 2017-01-01      48843              -2.810559
# 2017-01-02     136902              -0.527331
# 2017-01-03     148569              -0.224824
# 2017-01-04     139660              -0.455820
# 2017-01-05     146103              -0.288764
# ...               ...                    ...
# 2024-10-20     106959              -1.303704
# 2024-10-21     184116               0.696852
# 2024-10-22     207815               1.311329
# 2024-10-23     197911               1.054534
# 2024-10-24     208828               1.337595
#
# [1758 rows x 2 columns]

# %%
from sklearn.cluster import KMeans
afluencia_diaria = df['AFLUENCIA'].values
# Reshape los datos para K-means
afluencia_diaria = afluencia_diaria.reshape(-1, 1)
# Aplicar K-means con 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42).fit(afluencia_diaria)
clusters = kmeans.labels_  # Etiquetas de los clusters
centros = kmeans.cluster_centers_.flatten()
orden = np.argsort(centros)
#Establecer los estados
cluster_map = {orden[0]: "Baja", orden[1]: "Media", orden[2]: "Alta"}
clusters_clasificados = [cluster_map[c] for c in clusters]
#Agregar a la tabla de datos
df['CLUSTER'] = clusters
df['CLASFICACIÓN'] = [cluster_map[c] for c in clusters]
print("Clasificación de afluencia diaria:")
print(df.head())
# Out:
# Clasificación de afluencia diaria:
#             AFLUENCIA  AFLUENCIA NORMALIZADA  CLUSTER CLASFICACIÓN
# FECHA
# 2017-01-01      48843              -2.810559        0         Baja
# 2017-01-02     136902              -0.527331        2        Media
# 2017-01-03     148569              -0.224824        2        Media
# 2017-01-04     139660              -0.455820        2        Media
# 2017-01-05     146103              -0.288764        2        Media

# %%
df
# Out:
#             AFLUENCIA  AFLUENCIA NORMALIZADA  CLUSTER CLASFICACIÓN
# FECHA
# 2017-01-01      48843              -2.810559        0         Baja
# 2017-01-02     136902              -0.527331        2        Media
# 2017-01-03     148569              -0.224824        2        Media
# 2017-01-04     139660              -0.455820        2        Media
# 2017-01-05     146103              -0.288764        2        Media
# ...               ...                    ...      ...          ...
# 2024-10-20     106959              -1.303704        0         Baja
# 2024-10-21     184116               0.696852        1         Alta
# 2024-10-22     207815               1.311329        1         Alta
# 2024-10-23     197911               1.054534        1         Alta
# 2024-10-24     208828               1.337595        1         Alta
#
# [1758 rows x 4 columns]

# %%
df = pd.read_excel('AFLUENCIA_2023.xlsx', parse_dates=['FECHA'], index_col='FECHA')
#Normalización de los datos
scaler = StandardScaler()
# Normalizamos solo la columna de la afluencia diaria
df['Afluencia diaria normalizada'] = scaler.fit_transform(df[['AFLUENCIA']])

# %%
from sklearn.cluster import KMeans
afluencia_diaria = df['AFLUENCIA'].values
# Reshape los datos para K-means
afluencia_diaria = afluencia_diaria.reshape(-1, 1)
# Aplicar K-means con 3 clusters
kmeans = KMeans(n_clusters=3, random_state=42).fit(afluencia_diaria)
clusters = kmeans.labels_  # Etiquetas de los clusters
centros = kmeans.cluster_centers_.flatten()
orden = np.argsort(centros)
#Establecer los estados
cluster_map = {orden[0]: "Baja", orden[1]: "Media", orden[2]: "Alta"}
clusters_clasificados = [cluster_map[c] for c in clusters]
#Agregar a la tabla de datos
df['cluster'] = clusters
df['clasificacion'] = [cluster_map[c] for c in clusters]
print("Clasificación de afluencia diaria:")
print(df.head())
# Out:
# Clasificación de afluencia diaria:
#             AFLUENCIA  Afluencia diaria normalizada  cluster clasificacion
# FECHA
# 2023-01-01      45541                     -3.159183        1          Baja
# 2023-01-02     128298                     -0.938737        2         Media
# 2023-01-03     147638                     -0.419827        2         Media
# 2023-01-04     154646                     -0.231796        2         Media
# 2023-01-05     166177                      0.077591        0          Alta

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df.index, df['AFLUENCIA'], c=df['cluster'], cmap='viridis', edgecolors='black', linewidths=0.5) # Cambiado el mapa de colores
plt.title('Clusters de Afluencia Diaria', color='gray', fontsize = 12) # Cambiado el color del título
plt.xlabel('Fecha', color='gray', fontsize = 12) # Cambiado el color de la etiqueta
plt.ylabel('Afluencia Diaria', color='gray', fontsize = 12) # Cambiado el color de la etiqueta
plt.gca().set_facecolor('white') # Color de fondo del gráfico
plt.show()

# %%
# Identificar los estados únicos
estados_unicos = list(set(estados))
n_estados = len(estados_unicos)

# Crear un diccionario para asignar índices a los estados
estado_indices = {estado: i for i, estado in enumerate(estados_unicos)}

# Inicializar la matriz de transición con ceros
transiciones = np.zeros((n_estados, n_estados))

# Contar transiciones
for (estado_actual, estado_siguiente) in zip(estados[:-1], estados[1:]):
    i = estado_indices[estado_actual]
    j = estado_indices[estado_siguiente]
    transiciones[i, j] += 1

# Normalizar filas para obtener probabilidades
matriz_transicion = transiciones / transiciones.sum(axis=1, keepdims=True)

# Convertir a DataFrame para una mejor visualización
matriz_transicion_df = pd.DataFrame(
    matriz_transicion,
    index=estados_unicos,
    columns=estados_unicos
)

print("Matriz de Transición:")
print(matriz_transicion_df)
# Out:
# Matriz de Transición:
#           0         1         2
# 0  0.757720  0.040380  0.201900
# 1  0.630252  0.226891  0.142857
# 2  0.229508  0.606557  0.163934

# %%
# Calcular la media y la desviación estándar para cada estado
estadisticas_emision = df.groupby('clasificacion')['AFLUENCIA'].agg([np.mean, np.std])
emisiones = estadisticas_emision
emisiones
# Out:
# <ipython-input-575-988dbd5163ee>:2: FutureWarning:
#
# The provided callable <function mean at 0x7d46ae63d5a0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#
# <ipython-input-575-988dbd5163ee>:2: FutureWarning:
#
# The provided callable <function std at 0x7d46ae63d6c0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#                         mean           std
# clasificacion
# Alta           187843.255924  11687.985391
# Baja            98031.890756  14283.822165
# Media          141986.877049  13734.833820

# %%
# Media y desviación estándar de los clusters
B_means = estadisticas_emision['mean'].values  # Medias para cada estado
B_stds = estadisticas_emision['std'].values  # Desviaciones estándar para cada estado

# La distribución inicial de los estados (pi) puede estar basada en los primeros 100 valores
frecuencias_iniciales = np.bincount(df['cluster'][:100])  # Contar la frecuencia de los primeros estados
distribucion_inicial = frecuencias_iniciales / frecuencias_iniciales.sum()  # Normalizar

# %%
estados = df['cluster']
frecuencias_iniciales = np.bincount(estados[:100])  # Contar la frecuencia de los primeros estados
distribucion_inicial = frecuencias_iniciales / frecuencias_iniciales.sum()  # Normalizamos
print("Distribución Inicial de Estados:", distribucion_inicial)
# Out:
# Distribución Inicial de Estados: [0.51 0.25 0.24]

# %%
B_means = estadisticas_emision['mean'].values  # Medias para baja, media, alta afluencia
B_stds = estadisticas_emision['std'].values  # Desviaciones estándar para baja, media, alta afluencia


def ajustar_media_finde_semana(media, es_fin_de_semana):
    if es_fin_de_semana:
        return media * 0.5 # Reducir la media en un 30% para los fines de semana
    return media  # Para los días laborables, mantenemos la media igual

# Actualizar las medias para los fines de semana
B_means_ajustado = np.array([ajustar_media_finde_semana(mean, True) for mean in B_means])

# %%
# Función para generar una observación (afluencia) dado un estado y ajustada para fin de semana
np.random.seed(779)
def sample_observation(state, B_means, B_stds, es_fin_de_semana):
    """Muestra una observación (afluencia) dado el estado actual y ajustado para el fin de semana."""
    # Ajustar la media para los fines de semana
    mean_ajustada = B_means[state]  # Usamos la media estándar
    if es_fin_de_semana:
        mean_ajustada = B_means_ajustado[state]  # Usar la media ajustada para los fines de semana
    return np.random.normal(mean_ajustada, B_stds[state])
def sample_next_state(current_state, transition_matrix, es_fin_de_semana):
    """Samples the next state based on the transition probabilities."""
    # The next state is sampled based on the transition probabilities for the current state
    return np.random.choice(range(transition_matrix.shape[1]), p=transition_matrix[current_state])

# Inicialización de la simulación
current_state = np.random.choice(range(n_estados), p=distribucion_inicial)  # Elegir el estado inicial
predicted_states = [current_state]
predicted_observations = [sample_observation(current_state, B_means, B_stds, False)]  # Iniciamos sin fin de semana

# Simulación para los próximos 7 días
for i in range(7):  # Para los próximos 7 días
    # Calcular si el día estimado es fin de semana
    predicted_date = df.index[-1] + pd.Timedelta(days=i+1)  # Fecha estimada del siguiente día
    es_fin_de_semana = predicted_date.weekday() == 6  # Si el día es sábado (5) o domingo (6), es fin de semana

    # Realizar la transición y generar la observación para ese día
    current_state = sample_next_state(current_state, matriz_transicion, es_fin_de_semana)
    predicted_states.append(current_state)
    predicted_observations.append(sample_observation(current_state, B_means, B_stds, es_fin_de_semana))

# Crear un DataFrame para las predicciones
predicted_dates = pd.date_range(df.index[-1] + pd.Timedelta(days=1), periods=7, freq='D')
predicted_df = pd.DataFrame(predicted_observations[1:], columns=['Afluencia estimada'], index=predicted_dates)

# Mostrar las predicciones
print("Predicción de los próximos 7 días con ajustes para fines de semana:")
print(predicted_df)
# Out:
# Predicción de los próximos 7 días con ajustes para fines de semana:
#             Afluencia estimada
# 2024-10-25       190070.630309
# 2024-10-26       153166.076113
# 2024-10-27        94849.964231
# 2024-10-28       172669.395321
# 2024-10-29       204269.360405
# 2024-10-30       200983.436100
# 2024-10-31       177759.073481

# %%
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['AFLUENCIA'], label='Afluencia Histórica', color='skyblue')
plt.plot(predicted_df.index, predicted_df['Afluencia estimada'], label='Afluencia Predicha', color='#8B0000', linestyle='--') # Changed to predicted_df.index
plt.legend()
plt.title('Predicción de afluencia para los próximos 7 días', fontsize = 12)
plt.xlabel('Fecha',fontsize = 12)
plt.ylabel('Afluencia',fontsize = 12)
plt.show()

# %% [markdown]
# ERROR CUADRATICO MEDIO

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
y_real = [198491,151848,93165,185470,203048,203777,205492]
y_predicho = predicted_df['Afluencia estimada'].values
mae = mean_absolute_error(y_real, y_predicho)
relativo = mae / np.mean(y_real) * 100
print(relativo)
print(f"MAE relativo: {relativo:.2f}%")
# Out:
# 4.509165500878784
# MAE relativo: 4.51%

# %%
y_predicho = [int(value) for value in y_predicho]

# %%
results_df = pd.DataFrame({'FECHA': predicted_dates,'ALFUENCIA REAL': y_real, 'AFLUENCIA ESTIMADA': y_predicho})
results_df
# Out:
#        FECHA  ALFUENCIA REAL  AFLUENCIA ESTIMADA
# 0 2024-10-25          198491              190070
# 1 2024-10-26          151848              153166
# 2 2024-10-27           93165               94849
# 3 2024-10-28          185470              172669
# 4 2024-10-29          203048              204269
# 5 2024-10-30          203777              200983
# 6 2024-10-31          205492              177759

# %%
seed = []
c = 0

# %%
for i in range(1000):
  np.random.seed(i)
  def sample_observation(state, B_means, B_stds, es_fin_de_semana):
    """Muestra una observación (afluencia) dado el estado actual y ajustado para el fin de semana."""
    # Ajustar la media para los fines de semana
    mean_ajustada = B_means[state]  # Usamos la media estándar
    if es_fin_de_semana:
        mean_ajustada = B_means_ajustado[state]  # Usar la media ajustada para los fines de semana
    return np.random.normal(mean_ajustada, B_stds[state])
  def sample_next_state(current_state, transition_matrix, es_fin_de_semana):
    """Samples the next state based on the transition probabilities."""
    # The next state is sampled based on the transition probabilities for the current state
    return np.random.choice(range(transition_matrix.shape[1]), p=transition_matrix[current_state])

# Inicialización de la simulación
  current_state = np.random.choice(range(n_estados), p=distribucion_inicial)  # Elegir el estado inicial
  predicted_states = [current_state]
  predicted_observations = [sample_observation(current_state, B_means, B_stds, False)]  # Iniciamos sin fin de semana

# Simulación para los próximos 7 días
  for i in range(7):  # Para los próximos 7 días
    # Calcular si el día estimado es fin de semana
    predicted_date = df.index[-1] + pd.Timedelta(days=i+1)  # Fecha estimada del siguiente día
    es_fin_de_semana = predicted_date.weekday() == 6  # Si el día es sábado (5) o domingo (6), es fin de semana

    # Realizar la transición y generar la observación para ese día
    current_state = sample_next_state(current_state, matriz_transicion, es_fin_de_semana)
    predicted_states.append(current_state)
    predicted_observations.append(sample_observation(current_state, B_means, B_stds, es_fin_de_semana))

# Crear un DataFrame para las predicciones
  predicted_dates = pd.date_range(df.index[-1] + pd.Timedelta(days=1), periods=7, freq='D')
  predicted_df = pd.DataFrame(predicted_observations[1:], columns=['Afluencia estimada'], index=predicted_dates)


  y_real = [198491,151848,93165,185470,203048,203777,205492]
  y_predicho = predicted_df['Afluencia estimada'].values
  mae = mean_absolute_error(y_real, y_predicho)
  relativo = mae / np.mean(y_real) * 100
  seed.append(relativo)

# %%
np.min(seed)
# Out:
# 4.384545802921086

# %%
position = seed.index(4.509165500878784)
position
# Out:
# 779
